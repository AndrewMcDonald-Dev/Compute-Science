# %% [markdown]
# # HW 1
#
# ### Setup

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### #1

# %%
image1 = np.array([50,75,100,125,150,175,200,225,250])
image2 = np.array([[50,75,100],[125,150,175],[200,225,250]])
print(image1)
print(image2)
# Out:
# [ 50  75 100 125 150 175 200 225 250]
# [[ 50  75 100]
#  [125 150 175]
#  [200 225 250]]

# %% [markdown]
# ### #2

# %%
print(image1[4])
# Out:
# 150

# %% [markdown]
# ### #3

# %%
print(image2[1][1])
# Out:
# 150

# %% [markdown]
# ### #4

# %%
image3 = cv2.imread('Simple.webp', 1)
plt.imshow(image3)
